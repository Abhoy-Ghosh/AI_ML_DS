# %% [markdown]
# In python ,modules and Packages help organize and reuse code.Here discuss about import them

# %% [markdown]
# import _packageName_ (like math)
# packageName.function()
#
# from _packageName_ import _functionName_(like sqrt,pi)
# from _packageName_ import (* for all)
# from math import sqrt,pi
# print(sqrt(16))
# print(pi)
#
# to install package
# way1
# pip install -r requirement.txt //carring all requirement modules or packages
#
# way2
# pip install numpy

# %%
import numpy as np 
np.array([1,2,3,4])
# Out:
# array([1, 2, 3, 4])

# %%
from ownCustomPackage.customMaths import addition
addition(2,4)
# Out:
# 6
