# %% [markdown]
# 🔴 Case 1 — Overfitting
# Train Score  → High (≈1.0)
# CV Score     → Low
#
# 👉 Model memorizing data
# 👉 Fix:
#
# Regularization (C ↓)
# Simpler model
# More data
#
#
#
# 🔵 Case 2 — Underfitting
# Train Score  → Low
# CV Score     → Low
#
# 👉 Model too simple
# 👉 Fix:
#
# Increase model complexity
# Add features
#
#
#
# 🟢 Case 3 — Good Model
# Train Score ≈ CV Score (both high)
#
# 👉 Balanced model
# 👉 Good generalization
#
#
#
#
# 🟡 Case 4 — High variance (needs more data)
# Gap between Train and CV is large but shrinking
#
# 👉 More data will help
